# %%
import pandas as pd 
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
gdf = pd.read_csv(r'C:\Users\ugur\Desktop\nba.games.stats.csv')
gdf.columns
# Out:
# Index(['Unnamed: 0', 'Team', 'Game', 'Date', 'Home', 'Opponent', 'WINorLOSS',
#        'TeamPoints', 'OpponentPoints', 'FieldGoals', 'FieldGoalsAttempted',
#        'FieldGoals.', 'X3PointShots', 'X3PointShotsAttempted', 'X3PointShots.',
#        'FreeThrows', 'FreeThrowsAttempted', 'FreeThrows.', 'OffRebounds',
#        'TotalRebounds', 'Assists', 'Steals', 'Blocks', 'Turnovers',
#        'TotalFouls', 'Opp.FieldGoals', 'Opp.FieldGoalsAttempted',
#        'Opp.FieldGoals.', 'Opp.3PointShots', 'Opp.3PointShotsAttempted',
#        'Opp.3PointShots.', 'Opp.FreeThrows', 'Opp.FreeThrowsAttempted',
#        'Opp.FreeThrows.', 'Opp.OffRebounds', 'Opp.TotalRebounds',
#        'Opp.Assists', 'Opp.Steals', 'Opp.Blocks', 'Opp.Turnovers',
#        'Opp.TotalFouls'],
#       dtype='object')

# %%
gdf['WINorLOSS'] = gdf['WINorLOSS'].replace(['W', 'L'], [1,0]).astype(str).astype(int)
gdf['Home'] = gdf['Home'].replace(['Home', 'Away'], [1,0]).astype(str).astype(int)
gdf['Month'] = [int(m[5:7]) for m in gdf['Date']]
gdf['Year'] = [int(y[:4]) for y in gdf['Date']]

def seasons(d):
  m=d[5:7]
  y=d[:4] 
  if (y =='2014'):
    s='one'
  elif (y=='2015'):
    s='two'
  elif (y=='2016'):
    s='three'
  else:
    s='four'
  return (s)
gdf['Season']=gdf['Date'].apply(seasons)

# %%
gdf.drop('Date', inplace=True, axis=1)

# %%
gdf.head(5)
# Out:
#    Unnamed: 0 Team  Game  Home Opponent  WINorLOSS  TeamPoints  \
# 0           1  ATL     1     0      TOR          0         102
# 1           2  ATL     2     1      IND          1         102
# 2           3  ATL     3     0      SAS          0          92
# 3           4  ATL     4     0      CHO          0         119
# 4           5  ATL     5     1      NYK          1         103
#
#    OpponentPoints  FieldGoals  FieldGoalsAttempted  ...  Opp.OffRebounds  \
# 0             109          40                   80  ...               16
# 1              92          35                   69  ...               11
# 2              94          38                   92  ...               11
# 3             122          43                   93  ...               11
# 4              96          33                   81  ...               13
#
#    Opp.TotalRebounds  Opp.Assists  Opp.Steals  Opp.Blocks  Opp.Turnovers  \
# ...

# %%
gswdf = gdf[gdf.Team == 'GSW']

# %%
print(gswdf)
# Out:
#       Unnamed: 0 Team  Game  Home Opponent  WINorLOSS  TeamPoints  \
# 738          130  GSW     1     0      SAC          1          95
# 739          230  GSW     2     1      LAL          1         127
# 740          330  GSW     3     0      POR          1          95
# 741          430  GSW     4     1      LAC          1         121
# 742          530  GSW     5     0      HOU          1          98
# ...          ...  ...   ...   ...      ...        ...         ...
# 8195        7899  GSW    78     0      OKC          1         111
# 8196        7999  GSW    79     0      IND          0         106
# 8197        8099  GSW    80     1      NOP          0         120
# 8198       81104  GSW    81     0      PHO          1         117
# 8199        8299  GSW    82     0      UTA          0          79
#
#       OpponentPoints  FieldGoals  FieldGoalsAttempted  ...  Opp.OffRebounds  \
# 738               77          33                   75  ...               15
# ...

# %%
gswdf.TeamPoints.hist()
# Out:
# <AxesSubplot:>

# %%
gswmeanpts = gswdf.TeamPoints.mean()
print(gswmeanpts)
# Out:
# 113.54878048780488

# %%
gswsdopp = gswdf.OpponentPoints.std()
print("Golden State OppPoints SD ", gswsdopp)
# Out:
# Golden State OppPoints SD  11.711428902684846

# %%
Lakersdata = gdf[gdf.Team == "LAL"] 
BOSdata = gdf[gdf.Team == "BOS"]
ATLdata = gdf[gdf.Team == "ATL"] 
WASdata = gdf[gdf.Team == "WAS"]
GSWdata = gdf[gdf.Team == 'GSW']

# %%
Lakers = np.mean(Lakersdata.TeamPoints) 
LakersAssists = np.mean(Lakersdata.Assists) 
LakersTotalRebounds = np.mean(Lakersdata.TotalRebounds) 
LakersOpponentPoints = np.mean(Lakersdata.OpponentPoints)

# %%
Boston = np.mean(BOSdata.TeamPoints) 
BostonAssists = np.mean(BOSdata.Assists) 
BostonTotalRebounds = np.mean(BOSdata.TotalRebounds) 
BostonOpponentPoints = np.mean(BOSdata.OpponentPoints)

# %%
Atlanta = np.mean(ATLdata.TeamPoints) 
AtlantaAssists = np.mean(ATLdata.Assists) 
AtlantaTotalRebounds = np.mean(ATLdata.TotalRebounds) 
AtlantaOpponentPoints = np.mean(ATLdata.OpponentPoints)

# %%
Washington = np.mean(WASdata.TeamPoints) 
WashingtonAssists = np.mean(WASdata.Assists) 
WashingtonTotalRebounds = np.mean(WASdata.TotalRebounds) 
WashingtonOpponentPoints = np.mean(WASdata.OpponentPoints)

# %%
GoldenState = np.mean(GSWdata.TeamPoints) 
GoldenStateAssists = np.mean(GSWdata.Assists) 
GoldenStateTotalRebounds = np.mean(GSWdata.TotalRebounds) 
GoldenStateOpponentPoints = np.mean(GSWdata.OpponentPoints)

# %%
data1 = {'TeamName': ["LAL","GSW","BOS","ATL","WAS"],'AverageTeamPoints': [Lakers, GoldenState,Boston,Atlanta,Washington],
       'AverageAssists' : [LakersAssists,GoldenStateAssists,BostonAssists,AtlantaAssists,WashingtonAssists],
       'AverageTotalRebounds' : [LakersTotalRebounds,GoldenStateTotalRebounds,BostonTotalRebounds,AtlantaTotalRebounds,WashingtonTotalRebounds],
       'AverageOpponentPoints' : [LakersOpponentPoints,GoldenStateOpponentPoints,BostonOpponentPoints,AtlantaOpponentPoints,WashingtonOpponentPoints],
       'AverageEff' : [average_eff_Lakers,average_eff_GSWdata,average_eff_BOSdata,average_eff_ATLdata,average_eff_WASdata] 
       }
df1 = pd.DataFrame(data1)
df1
# Out:
#   TeamName  AverageTeamPoints  AverageAssists  AverageTotalRebounds  \
# 0      LAL         102.109756       20.908537             44.185976
# 1      GSW         113.548780       29.006098             44.713415
# 2      BOS         104.777439       24.088415             43.795732
# 3      ATL         102.975610       24.679878             42.216463
# 4      WAS         104.600610       24.375000             43.121951
#
#    AverageOpponentPoints  AverageEff
# 0             108.317073  -14.713415
# 1             103.932927   23.033537
# 2             102.381098    3.439024
# 3             102.292683   -0.265244
# 4             103.948171    3.454268

# %%
sns.catplot(x="OpponentPoints", y="TeamPoints", data=Lakersdata , hue = "WINorLOSS",height=8, aspect=20/8);

# %%
sns.catplot(x="OpponentPoints", y="TeamPoints", data=BOSdata , hue = "WINorLOSS",height=8, aspect=20/8);

# %%
sns.catplot(x="OpponentPoints", y="TeamPoints", data=ATLdata , hue = "WINorLOSS",height=8, aspect=20/8);

# %%
sns.catplot(x="OpponentPoints", y="TeamPoints", data=WASdata , hue = "WINorLOSS",height=8, aspect=20/8);

# %%
sns.catplot(x="OpponentPoints", y="TeamPoints", data=GSWdata , hue = "WINorLOSS",height=8, aspect=20/8);

# %%
sns.catplot(x="Assists", y="TeamPoints", data=GSWdata , hue = "WINorLOSS",height=8, aspect=20/8);

# %%
sns.catplot(x="Turnovers", y="Opp.Assists", data=Lakersdata , hue = "WINorLOSS",height=8, aspect=20/8);

# %%
sns.catplot(x="Turnovers", y="Assists", data=Lakersdata , hue = "WINorLOSS",height=8, aspect=20/8);

# %%
sns.catplot(x="OpponentPoints", y="Turnovers", data=GSWdata , hue = "WINorLOSS",height=8, aspect=20/8);

# %%
sns.catplot(x="TeamPoints", y="Turnovers", data=BOSdata , hue = "WINorLOSS",height=8, aspect=20/8);

# %%
sns.catplot(x="Assists", y="TeamPoints", data=BOSdata , hue = "WINorLOSS",height=8, aspect=20/8);

# %%
# Calculated average EFF

# `(PTS + REB + AST + STL + BLK 
# − ((FGA − FGM) + (FTA − FTM) + TO))`

# %%
average_eff_Lakers = ((
    Lakersdata['TeamPoints'].mean() + 
    Lakersdata['Assists'].mean() + 
    Lakersdata['Steals'].mean() + 
    Lakersdata['Blocks'].mean() + 
    Lakersdata['TotalRebounds'].mean() + 
        Lakersdata['FieldGoals'].mean() +
        Lakersdata['FreeThrows'].mean()
    ) - (
        Lakersdata['OpponentPoints'].mean() +
        Lakersdata['Opp.Assists'].mean() +
        Lakersdata['Opp.Steals'].mean() +
        Lakersdata['Opp.Blocks'].mean() +
        Lakersdata['Opp.TotalRebounds'].mean() + 
        Lakersdata['Opp.FreeThrows'].mean() +
        Lakersdata['Opp.FieldGoals'].mean() ))
print(average_eff_Lakers)
# Out:
# -14.71341463414629

# %%
average_eff_BOSdata = ((
    BOSdata['TeamPoints'].mean() + 
    BOSdata['Assists'].mean() + 
    BOSdata['Steals'].mean() + 
    BOSdata['Blocks'].mean() + 
    BOSdata['TotalRebounds'].mean() + 
        BOSdata['FieldGoals'].mean() +
        BOSdata['FreeThrows'].mean()
    ) - (
        BOSdata['OpponentPoints'].mean() +
        BOSdata['Opp.Assists'].mean() +
        BOSdata['Opp.Steals'].mean() +
        BOSdata['Opp.Blocks'].mean() +
        BOSdata['Opp.TotalRebounds'].mean() + 
        BOSdata['Opp.FreeThrows'].mean() +
        BOSdata['Opp.FieldGoals'].mean() ))
print(average_eff_BOSdata)
# Out:
# 3.439024390243901

# %%
Lakersdata = gdf[gdf.Team == "LAL"] 
BOSdata = gdf[gdf.Team == "BOS"]
ATLdata = gdf[gdf.Team == "ATL"] 
WASdata = gdf[gdf.Team == "WAS"]
GSWdata = gdf[gdf.Team == 'GSW']

# %%
average_eff_ATLdata = ((
    ATLdata['TeamPoints'].mean() + 
    ATLdata['Assists'].mean() + 
    ATLdata['Steals'].mean() + 
    ATLdata['Blocks'].mean() + 
    ATLdata['TotalRebounds'].mean() + 
        ATLdata['FieldGoals'].mean() +
        ATLdata['FreeThrows'].mean()
    ) - (
        ATLdata['OpponentPoints'].mean() +
        ATLdata['Opp.Assists'].mean() +
        ATLdata['Opp.Steals'].mean() +
        ATLdata['Opp.Blocks'].mean() +
        ATLdata['Opp.TotalRebounds'].mean() + 
        ATLdata['Opp.FreeThrows'].mean() +
        ATLdata['Opp.FieldGoals'].mean() ))
print(average_eff_ATLdata)
# Out:
# -0.2652439024390105

# %%
average_eff_WASdata = ((
    WASdata['TeamPoints'].mean() + 
    WASdata['Assists'].mean() + 
    WASdata['Steals'].mean() + 
    WASdata['Blocks'].mean() + 
    WASdata['TotalRebounds'].mean() + 
        WASdata['FieldGoals'].mean() +
        WASdata['FreeThrows'].mean()
    ) - (
        WASdata['OpponentPoints'].mean() +
        WASdata['Opp.Assists'].mean() +
        WASdata['Opp.Steals'].mean() +
        WASdata['Opp.Blocks'].mean() +
        WASdata['Opp.TotalRebounds'].mean() + 
        WASdata['Opp.FreeThrows'].mean() +
        WASdata['Opp.FieldGoals'].mean() ))
print(average_eff_WASdata)
# Out:
# 3.45426829268294

# %%
average_eff_GSWdata = ((
    GSWdata['TeamPoints'].mean() + 
    GSWdata['Assists'].mean() + 
    GSWdata['Steals'].mean() + 
    GSWdata['Blocks'].mean() + 
    GSWdata['TotalRebounds'].mean() + 
        GSWdata['FieldGoals'].mean() +
        GSWdata['FreeThrows'].mean()
    ) - (
        GSWdata['OpponentPoints'].mean() +
        GSWdata['Opp.Assists'].mean() +
        GSWdata['Opp.Steals'].mean() +
        GSWdata['Opp.Blocks'].mean() +
        GSWdata['Opp.TotalRebounds'].mean() + 
        GSWdata['Opp.FreeThrows'].mean() +
        GSWdata['Opp.FieldGoals'].mean() ))
print(average_eff_GSWdata)
# Out:
# 23.03353658536588

# %%
print(Lakersdata)
# Out:
#       Unnamed: 0 Team  Game  Home Opponent  WINorLOSS  TeamPoints  \
# 1066         170  LAL     1     1      HOU          0          90
# 1067         270  LAL     2     0      PHO          0          99
# 1068         370  LAL     3     1      LAC          0         111
# 1069         470  LAL     4     0      GSW          0         104
# 1070         570  LAL     5     1      PHO          0         106
# ...          ...  ...   ...   ...      ...        ...         ...
# 8523       78103  LAL    78     1      SAS          1         122
# 8524       79103  LAL    79     1      MIN          0          96
# 8525       80103  LAL    80     1      UTA          0          97
# 8526       81108  LAL    81     1      HOU          0          99
# 8527       82103  LAL    82     0      LAC          1         115
#
#       OpponentPoints  FieldGoals  FieldGoalsAttempted  ...  Opp.OffRebounds  \
# 1066             108          28                   79  ...               14
# ...

# %%
Lakersdata
# Out:
#       Unnamed: 0 Team  Game  Home Opponent  WINorLOSS  TeamPoints  \
# 1066         170  LAL     1     1      HOU          0          90
# 1067         270  LAL     2     0      PHO          0          99
# 1068         370  LAL     3     1      LAC          0         111
# 1069         470  LAL     4     0      GSW          0         104
# 1070         570  LAL     5     1      PHO          0         106
# ...          ...  ...   ...   ...      ...        ...         ...
# 8523       78103  LAL    78     1      SAS          1         122
# 8524       79103  LAL    79     1      MIN          0          96
# 8525       80103  LAL    80     1      UTA          0          97
# 8526       81108  LAL    81     1      HOU          0          99
# 8527       82103  LAL    82     0      LAC          1         115
#
#       OpponentPoints  FieldGoals  FieldGoalsAttempted  ...  Opp.OffRebounds  \
# 1066             108          28                   79  ...               14
# ...

# %%
gdf.head(5)
# Out:
#    Unnamed: 0 Team  Game  Home Opponent  WINorLOSS  TeamPoints  \
# 0           1  ATL     1     0      TOR          0         102
# 1           2  ATL     2     1      IND          1         102
# 2           3  ATL     3     0      SAS          0          92
# 3           4  ATL     4     0      CHO          0         119
# 4           5  ATL     5     1      NYK          1         103
#
#    OpponentPoints  FieldGoals  FieldGoalsAttempted  ...  Opp.OffRebounds  \
# 0             109          40                   80  ...               16
# 1              92          35                   69  ...               11
# 2              94          38                   92  ...               11
# 3             122          43                   93  ...               11
# 4              96          33                   81  ...               13
#
#    Opp.TotalRebounds  Opp.Assists  Opp.Steals  Opp.Blocks  Opp.Turnovers  \
# ...

# %%
gdf['WINorLOSS'] = gdf['WINorLOSS'].replace(['W', 'L'], [1,0]).astype(str).astype(int)
gdf['Home'] = gdf['Home'].replace(['Home', 'Away'], [1,0]).astype(str).astype(int)
gdf['Month'] = [int(m[5:7]) for m in gdf['Date']]
gdf['Year'] = [int(y[:4]) for y in gdf['Date']]

def seasons(d):
  m=d[5:7]
  y=d[:4] 
  if (y =='2014'):
    s='one'
  elif (y=='2015'):
    s='two'
  elif (y=='2016'):
    s='three'
  else:
    s='four'
  return (s)
gdf['Season']=gdf['Date'].apply(seasons)

# %%
gdf['Season']
# Out:
# 0        one
# 1        one
# 2        one
# 3        one
# 4        one
#         ...
# 9835    four
# 9836    four
# 9837    four
# 9838    four
# 9839    four
# Name: Season, Length: 9840, dtype: object

# %%
gdf.groupby(by=["Season"])

# %%
gdf.groupby(by=["Home"])

# %%
gdf
# Out:
#       Unnamed: 0 Team  Game  Home Opponent  WINorLOSS  TeamPoints  \
# 0              1  ATL     1     0      TOR          0         102
# 1              2  ATL     2     1      IND          1         102
# 2              3  ATL     3     0      SAS          0          92
# 3              4  ATL     4     0      CHO          0         119
# 4              5  ATL     5     1      NYK          1         103
# ...          ...  ...   ...   ...      ...        ...         ...
# 9835       78119  WAS    78     0      HOU          0         104
# 9836       79119  WAS    79     0      CLE          0         115
# 9837       80119  WAS    80     1      ATL          0          97
# 9838       81124  WAS    81     1      BOS          1         113
# 9839       82119  WAS    82     0      ORL          0          92
#
#       OpponentPoints  FieldGoals  FieldGoalsAttempted  ...  Opp.OffRebounds  \
# 0                109          40                   80  ...               16
# ...

# %%
BOSdatafour = BOSdata[BOSdata.Season == "four"]

# %%
BOSdatafour.head(3)
# Out:
#       Unnamed: 0 Team  Game  Home Opponent  WINorLOSS  TeamPoints  \
# 5036        3561  BOS    35     1      UTA          1         115
# 5037        3661  BOS    36     1      PHI          1         110
# 5038        3761  BOS    37     1      NOP          1         117
#
#       OpponentPoints  FieldGoals  FieldGoalsAttempted  ...  Opp.OffRebounds  \
# 5036             104          41                   74  ...                8
# 5037             106          35                   87  ...                4
# 5038             108          40                   93  ...                9
#
#       Opp.TotalRebounds  Opp.Assists  Opp.Steals  Opp.Blocks  Opp.Turnovers  \
# 5036                 35           27           7           3             10
# 5037                 41           30           9          11             15
# 5038                 42           22           7           7             11
#
#       Opp.TotalFouls  Month  Year  Season
# 5036              17      1  2017    four
# ...

# %%
BOSdataHomee = BOSdata[BOSdata.Home == "Home"]

# %%
BOSdataHomee
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, Team, Game, Home, Opponent, WINorLOSS, TeamPoints, OpponentPoints, FieldGoals, FieldGoalsAttempted, FieldGoals., X3PointShots, X3PointShotsAttempted, X3PointShots., FreeThrows, FreeThrowsAttempted, FreeThrows., OffRebounds, TotalRebounds, Assists, Steals, Blocks, Turnovers, TotalFouls, Opp.FieldGoals, Opp.FieldGoalsAttempted, Opp.FieldGoals., Opp.3PointShots, Opp.3PointShotsAttempted, Opp.3PointShots., Opp.FreeThrows, Opp.FreeThrowsAttempted, Opp.FreeThrows., Opp.OffRebounds, Opp.TotalRebounds, Opp.Assists, Opp.Steals, Opp.Blocks, Opp.Turnovers, Opp.TotalFouls, Month, Year, Season]
# Index: []
#
# [0 rows x 43 columns]

# %%
BOSdatafour
# Out:
#       Unnamed: 0 Team  Game  Home Opponent  WINorLOSS  TeamPoints  \
# 5036        3561  BOS    35     1      UTA          1         115
# 5037        3661  BOS    36     1      PHI          1         110
# 5038        3761  BOS    37     1      NOP          1         117
# 5039        3861  BOS    38     0      TOR          0         106
# 5040        3961  BOS    39     1      WAS          1         117
# ...          ...  ...   ...   ...      ...        ...         ...
# 7539        7891  BOS    78     0      TOR          0          78
# 7540        7991  BOS    79     1      CHI          1         111
# 7541        8091  BOS    80     1      ATL          0         106
# 7542        8193  BOS    81     0      WAS          0         101
# 7543        8291  BOS    82     1      BRK          1         110
#
#       OpponentPoints  FieldGoals  FieldGoalsAttempted  ...  Opp.OffRebounds  \
# 5036             104          41                   74  ...                8
# ...

# %%
BOSdatafour.head(20)
# Out:
#       Unnamed: 0 Team  Game  Home Opponent  WINorLOSS  TeamPoints  \
# 5036        3561  BOS    35     1      UTA          1         115
# 5037        3661  BOS    36     1      PHI          1         110
# 5038        3761  BOS    37     1      NOP          1         117
# 5039        3861  BOS    38     0      TOR          0         106
# 5040        3961  BOS    39     1      WAS          1         117
# 5041        4061  BOS    40     0      ATL          1         103
# 5042       41100  BOS    41     1      CHO          1         108
# 5043        4263  BOS    42     1      NYK          0         106
# 5044        4361  BOS    43     1      POR          0         123
# 5045        4461  BOS    44     0      WAS          0         108
# 5046        4561  BOS    45     1      HOU          1         120
# 5047        4661  BOS    46     1      ORL          1         128
# 5048        4761  BOS    47     0      MIL          1         112
# ...

# %%
sns.catplot(x="Season", y="FieldGoals",kind="swarm", data=BOSdata);

# %%
sns.catplot(x="Season", y="FieldGoals",kind="swarm", data=GSWdata);

# %%
sns.catplot(x="Home", y="Season",hue="WINorLOSS", data=GSWdata);

# %%
sns.catplot(x="Home", y="TeamPoints", hue="WINorLOSS", kind="bar", data=GSWdata);
